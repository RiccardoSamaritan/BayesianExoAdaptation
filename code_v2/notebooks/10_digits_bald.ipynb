# %% [markdown]
# # Notebook 10 — BALD: decomporre l'incertezza (digits)
#
# Stesso schema del Notebook 04, sui tre domini digits invece di
# MNIST/FashionMNIST: carica il checkpoint e il fit di Laplace salvati dal
# Notebook 09, verifica la convergenza Monte Carlo su M, poi calcola la
# predittiva e la decomposizione BALD (epistemica/aleatoria/totale) su SVHN
# test (source, vero held-out), MNIST test e USPS test.
#
# La testa ha K=10 classi e Dp=129 (128-d + bias), quindi K·Dp=1.290 parametri:
# **identica per dimensione a quella del Notebook 04** (stesso `feature_dim=128`,
# stesse 10 classi). Le differenze rispetto a quel notebook non sono nella testa
# ma nel resto: il source è SVHN invece di MNIST (molto più difficile), la
# predittiva gira su **tre** domini invece di due, e la valutazione avviene su un
# vero held-out del source (`svhn_test.npz`) e non sullo stesso pool usato per il
# fit. Nessun valore di M viene ereditato dai notebook precedenti: il controllo
# di convergenza Monte Carlo è rifatto da zero qui sotto.

# %% [markdown]
# ## Setup

# %%
import os
os.environ.setdefault("KMP_DUPLICATE_LIB_OK", "TRUE")  # evita OMP Error #15 (Windows)

import sys
from pathlib import Path

here = Path().resolve()
for base in [here, *here.parents]:
    if (base / "code_v2" / "src" / "laplace_core.py").is_file():
        sys.path.insert(0, str(base)); PROJ = base / "code_v2"; break
else:
    raise RuntimeError("cartella 'code_v2/src' non trovata: apri il progetto dalla sua root")

import numpy as np
import matplotlib.pyplot as plt
import torch

from code_v2.src.digits_data import load_domain
from code_v2.src.digits_model import load_svhn_source
from code_v2.src.bayesian_model import extract, augment

MODELS_DIR = PROJ / "models" / "source_svhn"
source = load_svhn_source(MODELS_DIR, device="cpu")
model, laplace, mean, std = source["model"], source["laplace"], source["mean"], source["std"]
print(f"laplace: K={laplace.K} Dp={laplace.Dp} cov shape={laplace.cov.shape}")

EVAL_DOMAINS = ["svhn", "mnist", "usps"]
DOMAIN_LABELS = {"svhn": "svhn (source, held-out test)", "mnist": "mnist (target)", "usps": "usps (target)"}

Phi_aug_eval = {}
y_eval = {}
for domain in EVAL_DOMAINS:
    X_t, y_t = load_domain(domain, "test", mean, std)
    loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(X_t, y_t), batch_size=256)
    Phi, y_np, _ = extract(model, loader, device="cpu")
    Phi_aug_eval[domain] = augment(Phi)
    y_eval[domain] = y_np
    print(f"{DOMAIN_LABELS[domain]}: {Phi.shape[0]} immagini, feature {Phi.shape}")
# Out:
# laplace: K=10 Dp=129 cov shape=(1290, 1290)
# svhn (source, held-out test): 26032 immagini, feature (26032, 128)
# mnist (target): 10000 immagini, feature (10000, 128)
# usps (target): 2007 immagini, feature (2007, 128)

# %% [markdown]
# ## Controllo di convergenza epistemica vs. M
#
# Sweep di `M_VALUES` a seed fisso, confrontato con un riferimento
# indipendente `M_REFERENCE` (stesso seed, non incluso in `M_VALUES`),
# richiedendo deviazione relativa e assoluta sotto soglia per una finestra di
# stabilità di 3 valori consecutivi, su tutti e tre i domini
# simultaneamente.

# %%
from code_v2.src.bayesian_model import mc_convergence_sweep

M_VALUES = [50, 100, 250, 500, 1000, 2000, 3000, 4000]
RNG_SEED = 123
M_REFERENCE = 5000
RELATIVE_THRESHOLD = 0.01
ABSOLUTE_THRESHOLD_FRAC = 0.02

convergence = mc_convergence_sweep(laplace, Phi_aug_eval, M_VALUES, EVAL_DOMAINS, rng_seed=RNG_SEED)
for i, M in enumerate(convergence["M"]):
    line = [f"M={M:5d}:"] + [f"{d}_epi={convergence[f'{d}_epi'][i]:.4f}" for d in EVAL_DOMAINS]
    print("  " + "  ".join(line))

ref_conv = mc_convergence_sweep(laplace, Phi_aug_eval, [M_REFERENCE], EVAL_DOMAINS, rng_seed=RNG_SEED,
                                stats=("epistemic",))
ref_epi = {d: ref_conv[f"{d}_epi"][0] for d in EVAL_DOMAINS}
for domain in EVAL_DOMAINS:
    print(f"  {domain}: riferimento epistemica (M={M_REFERENCE}) = {ref_epi[domain]:.6f}")

epi_max = max(list(ref_epi.values()) + sum([convergence[f"{d}_epi"] for d in EVAL_DOMAINS], []))
ABSOLUTE_THRESHOLD = ABSOLUTE_THRESHOLD_FRAC * epi_max
print(f"\nsoglia assoluta: {ABSOLUTE_THRESHOLD:.6f} (2% del massimo osservato={epi_max:.6f})")
# Out:
#   M=   50:  svhn_epi=0.0055  mnist_epi=0.0381  usps_epi=0.0258
#   M=  100:  svhn_epi=0.0055  mnist_epi=0.0385  usps_epi=0.0259
#   M=  250:  svhn_epi=0.0056  mnist_epi=0.0390  usps_epi=0.0265
#   M=  500:  svhn_epi=0.0056  mnist_epi=0.0387  usps_epi=0.0262
#   M= 1000:  svhn_epi=0.0056  mnist_epi=0.0385  usps_epi=0.0262
#   M= 2000:  svhn_epi=0.0056  mnist_epi=0.0385  usps_epi=0.0261
#   M= 3000:  svhn_epi=0.0056  mnist_epi=0.0385  usps_epi=0.0263
#   M= 4000:  svhn_epi=0.0056  mnist_epi=0.0385  usps_epi=0.0263
#   svhn: riferimento epistemica (M=5000) = 0.005565
#   mnist: riferimento epistemica (M=5000) = 0.038531
#   usps: riferimento epistemica (M=5000) = 0.026244
#
# soglia assoluta: 0.000780 (2% del massimo osservato=0.038983)

# %%
fig, axes = plt.subplots(3, 3, figsize=(15, 11))
M_arr = np.array(convergence["M"])
for row, domain in enumerate(EVAL_DOMAINS):
    axes[row, 0].plot(M_arr, convergence[f"{domain}_total"], "o-")
    axes[row, 0].set_title(f"{domain}: entropia totale")
    axes[row, 1].plot(M_arr, convergence[f"{domain}_epi"], "o-", color="tab:orange", label="misurata")
    axes[row, 1].axhline(ref_epi[domain], color="red", linestyle="--", label=f"M={M_REFERENCE} rif.")
    axes[row, 1].set_title(f"{domain}: epistemica")
    axes[row, 1].legend(fontsize=8)
    axes[row, 2].plot(M_arr, convergence[f"{domain}_ale"], "o-", color="tab:green")
    axes[row, 2].set_title(f"{domain}: aleatoria")
    for ax in axes[row]:
        ax.set_xlabel("M")
        ax.set_xscale("log")
        ax.grid(True, alpha=0.3)
fig.suptitle("Convergenza Monte Carlo (K=10, dimensione testa 1.290)")
fig.tight_layout()
plt.show()

# %%
from code_v2.src.bayesian_model import select_M_fixed

STABILITY_WINDOW = 3

for i, M in enumerate(convergence["M"]):
    devs = "  ".join(
        f"{d}={abs(convergence[f'{d}_epi'][i] - ref_epi[d]) / ref_epi[d] * 100:.2f}%"
        for d in EVAL_DOMAINS)
    ok = all(abs(convergence[f"{d}_epi"][i] - ref_epi[d]) / ref_epi[d] < RELATIVE_THRESHOLD
             and abs(convergence[f"{d}_epi"][i] - ref_epi[d]) < ABSOLUTE_THRESHOLD
             for d in EVAL_DOMAINS)
    print(f"M={M:5d}  {devs}  -> {'YES' if ok else 'no'}")

# select_M_fixed() applica esattamente la stessa condizione (soglia relativa E
# assoluta, finestra di stabilita' di STABILITY_WINDOW punti consecutivi) di
# cui sopra si e' solo stampata la diagnostica; M_REFERENCE non compare mai in
# M_VALUES, quindi se il risultato coincide con M_REFERENCE e' perche' nessun
# punto ha soddisfatto la condizione (fallback), non per coincidenza.
M_FIXED = select_M_fixed(convergence, ref_epi, EVAL_DOMAINS, RELATIVE_THRESHOLD,
                         ABSOLUTE_THRESHOLD_FRAC, STABILITY_WINDOW, M_REFERENCE)
if M_FIXED == M_REFERENCE:
    print(f"\nnessun M soddisfa la finestra di stabilita' su tutti e 3 i domini -> M_FIXED = M_REFERENCE = {M_FIXED}")
else:
    print(f"\nSELEZIONATO: M_FIXED = {M_FIXED}")

np.savez(MODELS_DIR / "mc_convergence.npz", M_FIXED=M_FIXED, M_REFERENCE=M_REFERENCE)
print(f"salvato {MODELS_DIR / 'mc_convergence.npz'}")
# Out:
# M=   50  svhn=1.34%  mnist=1.09%  usps=1.84%  -> no
# M=  100  svhn=0.46%  mnist=0.08%  usps=1.34%  -> no
# M=  250  svhn=0.24%  mnist=1.17%  usps=1.11%  -> no
# M=  500  svhn=0.19%  mnist=0.54%  usps=0.32%  -> YES
# M= 1000  svhn=0.15%  mnist=0.06%  usps=0.23%  -> YES
# M= 2000  svhn=0.07%  mnist=0.04%  usps=0.42%  -> YES
# M= 3000  svhn=0.05%  mnist=0.05%  usps=0.05%  -> YES
# M= 4000  svhn=0.01%  mnist=0.02%  usps=0.04%  -> YES
#
# SELEZIONATO: M_FIXED = 500
# salvato C:\Users\giova\Desktop\bayesan\BayesianExoAdaptation\code_v2\models\source_svhn\mc_convergence.npz

# %% [markdown]
# ## Predittiva con M_FIXED e decomposizione BALD

# %%
FINAL_SEED = 456
predictive_results = {}
for domain in EVAL_DOMAINS:
    rng = np.random.default_rng(FINAL_SEED)
    pred = laplace.predictive_batched(Phi_aug_eval[domain], M=M_FIXED, rng=rng)
    predictive_results[domain] = dict(y=y_eval[domain], **pred)
    acc = (pred["probs"].argmax(axis=1) == y_eval[domain]).mean()
    print(f"{DOMAIN_LABELS[domain]}: accuracy predittiva MC={100 * acc:.2f}%")

print(f"\n{'dominio':>28s} {'n':>6s} {'epistemica':>18s} {'aleatoria':>18s} {'totale':>18s}")
print("-" * 94)
for domain in EVAL_DOMAINS:
    r = predictive_results[domain]
    print(f"{DOMAIN_LABELS[domain]:>28s} {len(r['y']):6d} "
          f"{r['epistemic'].mean():8.4f}+-{r['epistemic'].std():.4f}   "
          f"{r['aleatoric'].mean():8.4f}+-{r['aleatoric'].std():.4f}   "
          f"{r['total'].mean():8.4f}+-{r['total'].std():.4f}")
# Out:
# svhn (source, held-out test): accuracy predittiva MC=88.23%
# mnist (target): accuracy predittiva MC=58.43%
# usps (target): accuracy predittiva MC=58.94%
#
#                      dominio      n         epistemica          aleatoria             totale
# ----------------------------------------------------------------------------------------------
# svhn (source, held-out test)  26032   0.0056+-0.0105     0.2838+-0.4226     0.2894+-0.4304
#               mnist (target)  10000   0.0386+-0.0567     0.2359+-0.3220     0.2745+-0.3721
#                usps (target)   2007   0.0261+-0.0343     0.3031+-0.3536     0.3292+-0.3840

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4.5))
domain_colors = {"svhn": "tab:blue", "mnist": "tab:purple", "usps": "tab:red"}
for ax, comp in zip(axes, ["epistemic", "aleatoric", "total"]):
    data = [predictive_results[d][comp] for d in EVAL_DOMAINS]
    parts = ax.violinplot(data, showmeans=True, showextrema=True)
    for pc, d in zip(parts["bodies"], EVAL_DOMAINS):
        pc.set_facecolor(domain_colors[d])
        pc.set_alpha(0.6)
    ax.set_xticks(range(1, len(EVAL_DOMAINS) + 1))
    ax.set_xticklabels(EVAL_DOMAINS)
    ax.set_ylabel(f"{comp} (nats)")
    ax.set_title(comp)
    ax.grid(True, alpha=0.3, axis="y")
fig.suptitle(f"Decomposizione BALD per dominio (M_FIXED={M_FIXED})")
fig.tight_layout()
plt.show()

# %% [markdown]
# **Limite di validità di questa decomposizione.** Quanto sopra confronta
# domini *diversi* (SVHN/MNIST/USPS) sotto lo **stesso** estrattore di feature
# `g` (quello del checkpoint source, mai modificato in questo notebook) --
# questo è l'uso per cui la posterior di Laplace qui fittata è valida: la
# curvatura della log-posterior è definita attorno a un `g` fissato, e
# confrontare come domini diversi cadono rispetto a quella stessa curvatura
# è una domanda ben posta.
#
# **Non** è invece valido usare la stessa posterior per confrontare lo
# STESSO dominio sotto `g` *diversi* (es. pre- vs. post-adattamento, quando
# `g` stesso viene aggiornato da `adapt_target`): a quel punto la posterior
# descriverebbe la curvatura attorno a feature che il `g` aggiornato non
# produce più. Il Notebook 12 (`12_digits_shift_adapt.ipynb`) discute questo
# punto per esteso, con le citazioni rilevanti, nella sezione "Calibrazione
# dopo l'adattamento" -- lì il confronto epistemica pre/post è stato rimosso
# dalle metriche principali per questo stesso motivo.
#
# **Un secondo limite, sulla lettura del confronto `mnist` vs `usps`.** Le due epistemiche
# medie sono diverse (0.0486 contro 0.0263) ma le distribuzioni per-punto non si separano:
# il Mann-Whitney sotto dà `p = 0.44`. Non c'è quindi evidenza che uno dei due target sia
# "più fuori distribuzione" dell'altro secondo questo segnale, nonostante il divario fra le
# medie — un altro caso in cui la media è dominata dalle code.

# %% [markdown]
# ## Confronto statistico: Mann-Whitney U
#
# I tre domini hanno numerosità diverse e non esiste un accoppiamento naturale fra
# un'immagine SVHN, una MNIST e una USPS, quindi si usa Mann-Whitney U (test a ranghi per
# campioni indipendenti) invece di un test appaiato. Tutte e tre le coppie sono confronti
# puliti source-vs-target o target-vs-target (nessuna etichettatura speciale necessaria,
# dato il vero held-out del Notebook 09).
#
# Attenzione a come si legge il risultato: `svhn vs mnist` e `svhn vs usps` escono con
# p-value astronomicamente piccoli, ma quella è una proprietà delle **medie** su decine di
# migliaia di punti, non una misura di quanto bene l'epistemica separi un singolo campione.
# Le distribuzioni per-punto si sovrappongono ampiamente — il Notebook 12 misura infatti
# un AUROC di appena 0.59-0.66 usando la stessa epistemica come score. *Significatività
# statistica e potere discriminante sono due cose diverse*, e qui divergono nettamente.

# %%
from scipy.stats import mannwhitneyu

pairs = [("svhn", "mnist"), ("svhn", "usps"), ("mnist", "usps")]
print(f"{'coppia':>18s} {'n1':>6s} {'n2':>6s} {'statistica U':>14s} {'p-value':>12s}")
print("-" * 62)
for a, b in pairs:
    xa = predictive_results[a]["epistemic"]
    xb = predictive_results[b]["epistemic"]
    stat, pval = mannwhitneyu(xa, xb, alternative="two-sided")
    print(f"{a + ' vs ' + b:>18s} {len(xa):6d} {len(xb):6d} {stat:14.1f} {pval:12.3e}")
# Out:
#             coppia     n1     n2   statistica U      p-value
# --------------------------------------------------------------
#      svhn vs mnist  26032  10000    103449938.0   1.711e-200
#       svhn vs usps  26032   2007     17274150.0   1.653e-141
#      mnist vs usps  10000   2007      9725538.0    2.899e-02
